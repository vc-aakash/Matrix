# %%
import pandas as pd
df = pd.read_csv('CSVExample.csv', sep =',')
df
# Out:
#                 Lead                 Title          Phone  \
# 0        Jim Grayson        Senior Manager  (555)761-2385
# 1  Prescilla Winston  Development Director  (555)218-3981
# 2     Melissa Potter      Head of Accounts  (555)791-3471
#
#                             Notes
# 0  Spoke Tuesday, he's interested
# 1    said to call again next week
# 2   Not interested, gave referral

# %%
import pandas as pd
# Tab separated file
df = pd.read_csv('datatab.txt', sep='\t', header = None)
print(df)
# Out:
#       0     1   2           3   4    5
# 0  This  file  is  seaparated  by  tab

# %%
# columns are separated by space 
df = pd.read_csv('data.txt', sep = ' ', header = None)
print(df)
# Out:
#       0   1  2    3      4   5
# 0  This  is  a  txt  file. NaN

# %%
f = open("data.txt", "r")
print(f.tell())
print(f.readline())
print(f.tell())
f.seek(f.tell()+2)
print(f.tell())
# Out:
# 0
# This is a text file.Added through code
# 38
# 40

# %%
f = open("data.txt", "a")
f.write(str(" Added through code"))
f.seek(0)
f = open("data.txt", "r")
print(f.read())
# Out:
# This is a text file. Added through code Added through code

# %%
import pandas as pd
#data=pd.read_excel('C:/Users/asahni/Documents/DAAI/Labs/FinancialSample.xlsx')
#data
data.to_csv('C:/Users/asahni/Documents/DAAI/Labs/FinancialSample2.xlsx')
data
data.to_excel('C:/Users/asahni/Documents/DAAI/Labs/FinancialSample2.xlsx')
data
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...
